# %%
from PyPDF2 import PdfReader          # for read and extract content from pdf
from langchain.text_splitter import RecursiveCharacterTextSplitter    # breaks/split long text into smaller pieces(chunks)

# %%
# pip install --upgrade langchain

# %%
import langchain
print(langchain.__version__)
# Out:
# 0.3.13

# %%
import PyPDF2
print(PyPDF2.__version__)
# Out:
# 3.0.1

# %%
import faiss                    # finding nearest neighbors or similarity between high-dimensional vectors ( vector similarity search )
print(faiss.__version__)
# Out:
# 1.7.4

# %%
#pip install tensorflow==2.11

# %%
# pip install -U langchain-community

# %%
from PyPDF2 import PdfReader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import SentenceTransformerEmbeddings          # generate embedding ( convert sentences or documents into numerical vector )
from langchain.vectorstores import FAISS

# %%
pdf_reader = PdfReader("Data_Science_Q_A_1605624753.pdf")
text=""
cnt=0
for page in pdf_reader.pages:
    text += page.extract_text()
    cnt +=1
#print(cnt)
    if cnt >=50:
        break

# %%
print(cnt)
# Out:
# 50

# %%
print(len(text))
# Out:
# 101493

# %%
print(text[:2500])
# Out:
# STATISTICS ........................................................................................................................................................... 6
# Q1. WHAT IS THE CENTRAL LIMIT THEOREM AND WHY IS IT IMPORTANT ? ........................................................................ 6
# Q2. WHAT IS SAMPLING ? HOW MANY SAMPLING METHODS DO YOU KNOW ? ................................................................... 7
# Q3. WHAT IS THE DIFFERENCE BETWEEN TYPE I VS TYPE II ERROR? .................................................................................. 9
# Q4. WHAT IS LINEAR REGRESSION ? WHAT DO THE TERMS P -VALUE, COEFFICIENT , AND R-SQUARED VALUE MEAN ? WHAT IS THE
# SIGNIFICANCE OF EACH OF THESE COMPONENTS ? ................................................................................................................. 9
# ...

# %%
print(text)
# Out:
# STATISTICS ........................................................................................................................................................... 6
# Q1. WHAT IS THE CENTRAL LIMIT THEOREM AND WHY IS IT IMPORTANT ? ........................................................................ 6
# Q2. WHAT IS SAMPLING ? HOW MANY SAMPLING METHODS DO YOU KNOW ? ................................................................... 7
# Q3. WHAT IS THE DIFFERENCE BETWEEN TYPE I VS TYPE II ERROR? .................................................................................. 9
# Q4. WHAT IS LINEAR REGRESSION ? WHAT DO THE TERMS P -VALUE, COEFFICIENT , AND R-SQUARED VALUE MEAN ? WHAT IS THE
# SIGNIFICANCE OF EACH OF THESE COMPONENTS ? ................................................................................................................. 9
# ...

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000 , chunk_overlap=200 , length_function=len)
chunks=text_splitter.split_text(text=text)

# %%
print(len(chunks))
# Out:
# 128

# %%
print(chunks[0])
# Out:
# STATISTICS ........................................................................................................................................................... 6
# Q1. WHAT IS THE CENTRAL LIMIT THEOREM AND WHY IS IT IMPORTANT ? ........................................................................ 6
# Q2. WHAT IS SAMPLING ? HOW MANY SAMPLING METHODS DO YOU KNOW ? ................................................................... 7
# Q3. WHAT IS THE DIFFERENCE BETWEEN TYPE I VS TYPE II ERROR? .................................................................................. 9
# Q4. WHAT IS LINEAR REGRESSION ? WHAT DO THE TERMS P -VALUE, COEFFICIENT , AND R-SQUARED VALUE MEAN ? WHAT IS THE
# SIGNIFICANCE OF EACH OF THESE COMPONENTS ? ................................................................................................................. 9

# %%
print(chunks[1])
# Out:
# SIGNIFICANCE OF EACH OF THESE COMPONENTS ? ................................................................................................................. 9
# Q5. WHAT ARE THE ASSUMPTIONS REQUIRED FOR LINEAR REGRESSION ? ........................................................................ 10
# Q6. WHAT IS A STATISTICAL INTERACTION ? .............................................................................................................. 10
# Q7. WHAT IS SELECTION BIAS ? .............................................................................................................................. 11
# Q8. WHAT IS AN EXAMPLE OF A DATA SET WITH A NON -GAUSSIAN DISTRIBUTION ? .......................................................... 11
# DATA SCIENCE .................................................................................................................................................... 12

# %%
# !pip install sentence-transformers

# %%
from sentence_transformers import SentenceTransformer
# Out:
# C:\Users\pavan\anaconda\envs\llm_env\lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# WARNING:tensorflow:From C:\Users\pavan\anaconda\envs\llm_env\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# pip install tf-keras

# %%
hf_model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")
# Out:
# C:\Users\pavan\anaconda\envs\llm_env\lib\site-packages\transformers\tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
embedding_model=SentenceTransformerEmbeddings(model=hf_model)
# Out:
# C:\Users\pavan\AppData\Local\Temp\ipykernel_45832\3780656627.py:1: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_model=SentenceTransformerEmbeddings(model=hf_model)
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 embedding_model=SentenceTransformerEmbeddings(model=hf_model)
#
# File ~\anaconda\envs\llm_env\lib\site-packages\langchain_core\_api\deprecation.py:216, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     214     warned = True
# ...

# %%
vector_store=FAISS.from_texts(texts=chunks , embedding=embedding_model)         # FAISS is also used for vector store
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 vector_store=FAISS.from_texts(texts=chunks , embedding=embedding_model)
#
# NameError: name 'embedding_model' is not defined

# %%
query = "Give any question"
docs = VectorStores.similarity_search(query=query , k=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 2
#       1 query = "Give any question"
# ----> 2 docs = VectorStores.similarity_search(query=query , k=3)
#
# NameError: name 'VectorStores' is not defined

# %%
query = ""
docs = vector_store.similarity_search(query=query, k=3)

# Print the results
for doc in docs:
    print(doc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 2
#       1 query = ""
# ----> 2 docs = vector_store.similarity_search(query=query, k=3)
#       4 # Print the results
#       5 for doc in docs:
#
# NameError: name 'vector_store' is not defined
